# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

## Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Paths of train and test dataset on Google drive

data_dir_train = pathlib.Path("/content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path("/content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Test")

## Paths of train and test dataset on local machine
# data_dir_train = pathlib.Path("Skin cancer ISIC The International Skin Imaging Collaboration/Train")
# data_dir_test = pathlib.Path("Skin cancer ISIC The International Skin Imaging Collaboration/Test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2243
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='training',
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 6743 files belonging to 9 classes.
# Using 5395 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='validation',
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 6743 files belonging to 9 classes.
# Using 1348 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.

class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here

# Number of target labels are 9
target_labels = 9

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation=tf.nn.relu),
  layers.Dense(target_labels)
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 9)                   │           1,161 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,989,801 (15.22 MB)
#  Trainable params: 3,989,801 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the model

# %%
# %%time
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2592s 3s/step - accuracy: 0.2603 - loss: 2.0196 - val_accuracy: 0.4837 - val_loss: 1.4119
# Epoch 2/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.4580 - loss: 1.4103 - val_accuracy: 0.5156 - val_loss: 1.2712
# Epoch 3/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.5645 - loss: 1.2004 - val_accuracy: 0.6157 - val_loss: 1.0765
# Epoch 4/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6379 - loss: 0.9875 - val_accuracy: 0.6647 - val_loss: 0.9512
# Epoch 5/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6804 - loss: 0.8706 - val_accuracy: 0.6818 - val_loss: 0.9235
# Epoch 6/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7605 - loss: 0.6716 - val_accuracy: 0.7418 - val_loss: 0.7833
# Epoch 7/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7987 - loss: 0.5541 - val_accuracy: 0.7537 - val_loss: 0.7636
# Epoch 8/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8373 - loss: 0.4643 - val_accuracy: 0.7782 - val_loss: 0.6900
# Epoch 9/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8848 - loss: 0.3424 - val_accuracy: 0.7953 - val_loss: 0.6399
# Epoch 10/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9011 - loss: 0.2991 - val_accuracy: 0.8227 - val_loss: 0.6147
# Epoch 11/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9080 - loss: 0.2698 - val_accuracy: 0.8108 - val_loss: 0.6271
# Epoch 12/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9273 - loss: 0.2008 - val_accuracy: 0.7982 - val_loss: 0.7644
# Epoch 13/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9332 - loss: 0.1979 - val_accuracy: 0.8056 - val_loss: 0.6882
# Epoch 14/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9268 - loss: 0.1921 - val_accuracy: 0.8301 - val_loss: 0.6386
# Epoch 15/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9387 - loss: 0.1606 - val_accuracy: 0.8042 - val_loss: 0.7560
# Epoch 16/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9439 - loss: 0.1468 - val_accuracy: 0.8309 - val_loss: 0.7145
# Epoch 17/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9564 - loss: 0.1209 - val_accuracy: 0.8286 - val_loss: 0.7449
# Epoch 18/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9519 - loss: 0.1278 - val_accuracy: 0.8249 - val_loss: 0.7501
# Epoch 19/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9499 - loss: 0.1216 - val_accuracy: 0.8108 - val_loss: 0.8481
# Epoch 20/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9404 - loss: 0.1509 - val_accuracy: 0.7997 - val_loss: 0.9016
# CPU times: user 1min 3s, sys: 9.25 s, total: 1min 12s
# Wall time: 44min 28s

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %% [markdown]
# ***Observations:***
#
# 1. The model's training accuracy shows a steady increase of upto 90%, while validation accuracy remains consistently around 55%.
#
# 2. A high training accuracy suggests the model has effectively captured the noise within the data. However, its poor performance on validation data indicates a lack of generalizability.
#
# 3. These observations confirm the presence of overfitting. To address this issue, augmentation techniques will be employed. Given the limited training data available, new samples will be generated by making slight modifications to existing data (such as horizontal/vertical image flipping, minor image rotations, etc.), which will then be used for training the model.

# %%
# After you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# Your code goes here

from tensorflow.keras import layers

augmentation_data = keras.Sequential([
    layers.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# %%
# Visualize how your augmentation strategy works for one instance of training image.
# Your code goes here

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        augmented_images = augmentation_data(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.title(class_names[labels[0]])
        plt.axis("off")

# %% [markdown]
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
from keras import layers

model = Sequential([
  augmentation_data,
  layers.Rescaling(1./255),
  layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation=tf.nn.relu),
  layers.Dense(target_labels)
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
# %%time
## Your code goes here, note: train your model for 20 epochs
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 11s 39ms/step - accuracy: 0.2013 - loss: 2.0584 - val_accuracy: 0.4221 - val_loss: 1.5311
# Epoch 2/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.4292 - loss: 1.5396 - val_accuracy: 0.4503 - val_loss: 1.4909
# Epoch 3/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.4588 - loss: 1.4310 - val_accuracy: 0.4844 - val_loss: 1.3801
# Epoch 4/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.4813 - loss: 1.3630 - val_accuracy: 0.5163 - val_loss: 1.2439
# Epoch 5/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.5335 - loss: 1.2372 - val_accuracy: 0.5556 - val_loss: 1.1728
# Epoch 6/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.5275 - loss: 1.2264 - val_accuracy: 0.5430 - val_loss: 1.1711
# Epoch 7/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.5500 - loss: 1.1714 - val_accuracy: 0.5497 - val_loss: 1.1727
# Epoch 8/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.5532 - loss: 1.1585 - val_accuracy: 0.5549 - val_loss: 1.1735
# Epoch 9/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.5746 - loss: 1.0982 - val_accuracy: 0.5994 - val_loss: 1.0495
# Epoch 10/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.5879 - loss: 1.0739 - val_accuracy: 0.6387 - val_loss: 0.9802
# Epoch 11/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.5982 - loss: 1.0410 - val_accuracy: 0.6499 - val_loss: 0.9644
# Epoch 12/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.6293 - loss: 0.9767 - val_accuracy: 0.6217 - val_loss: 0.9917
# Epoch 13/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.6388 - loss: 0.9661 - val_accuracy: 0.7018 - val_loss: 0.8340
# Epoch 14/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.6493 - loss: 0.9162 - val_accuracy: 0.6773 - val_loss: 0.8820
# Epoch 15/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.6734 - loss: 0.8578 - val_accuracy: 0.6424 - val_loss: 0.9870
# Epoch 16/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.6679 - loss: 0.8708 - val_accuracy: 0.7107 - val_loss: 0.8147
# Epoch 17/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.7082 - loss: 0.7826 - val_accuracy: 0.6766 - val_loss: 0.8681
# Epoch 18/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.7117 - loss: 0.7818 - val_accuracy: 0.7136 - val_loss: 0.7650
# Epoch 19/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.7144 - loss: 0.7501 - val_accuracy: 0.6929 - val_loss: 0.8486
# Epoch 20/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.7252 - loss: 0.7421 - val_accuracy: 0.6684 - val_loss: 0.9186
# CPU times: user 39.3 s, sys: 4.32 s, total: 43.6 s
# Wall time: 1min 39s

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# ***Observations:***
#
# 1. By leveraging augmented data, overfitting has been effectively addressed.
#
# 2. The training and validation accuracy of the aforementioned model fall within a similar range.
#
# 3. Both the training and validation data are showing poor performance, indicating that the model is now exhibiting underfitting.

# %% [markdown]
# #### Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.

from glob import glob

## find the image path for all class labels (lesions)
images_path_list = [ i for i in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]

## Extract the class labels (lesions)
lesions_list = [ os.path.basename(os.path.dirname(j)) for j in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]
print(len(lesions_list))
# Out:
# 2243

# %%
# Extract image path and class label in a dictionary
image_dict = dict(zip(images_path_list, lesions_list))
print(list(image_dict.items())[:5])
# Out:
# [('/content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026194.jpg', 'actinic keratosis'), ('/content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026525.jpg', 'actinic keratosis'), ('/content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025992.jpg', 'actinic keratosis'), ('/content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025780.jpg', 'actinic keratosis'), ('/content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025803.jpg', 'actinic keratosis')]

# %%
# View the image path and class label in a df
lesions_df = pd.DataFrame(list(image_dict.items()), columns=['Image Path', 'Label'])
lesions_df.head()
# Out:
#                                           Image Path              Label
# 0  /content/gdrive/My Drive/Skin cancer ISIC The ...  actinic keratosis
# 1  /content/gdrive/My Drive/Skin cancer ISIC The ...  actinic keratosis
# 2  /content/gdrive/My Drive/Skin cancer ISIC The ...  actinic keratosis
# 3  /content/gdrive/My Drive/Skin cancer ISIC The ...  actinic keratosis
# 4  /content/gdrive/My Drive/Skin cancer ISIC The ...  actinic keratosis

# %%
## Inspecting the distribution of classes in the data
lesions_df[['Label']].value_counts()
# Out:
# Label
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          380
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: count, dtype: int64

# %%
# Visualize the distribution of classes using a countplot

import seaborn as sns

plt.figure(figsize=(10, 8))
sns.countplot(y="Label", data=lesions_df)
plt.title('No. of images belonging to a Type v/s Types of Skin Lesion', fontsize=16)
plt.xlabel('No. of images in a particular skin lesion type', fontsize=14)
plt.ylabel('Skin Lesion Types', fontsize=14)
plt.show()

# %%
round(lesions_df[['Label']].value_counts(normalize=True)*100, 2)
# Out:
# Label
# pigmented benign keratosis    20.60
# melanoma                      19.53
# basal cell carcinoma          16.94
# nevus                         15.92
# squamous cell carcinoma        8.07
# vascular lesion                6.20
# actinic keratosis              5.08
# dermatofibroma                 4.24
# seborrheic keratosis           3.43
# Name: proportion, dtype: float64

# %% [markdown]
# #### Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# ***Observations:***
#
# 1. A clear class imbalance is evident within the training data.
#
# 2. The class **"seborrheic keratosis"** comprises the smallest proportion of samples, accounting for approximately **3.44%**.
#
# 3. **"Pigmented benign keratosis"** and **"melanoma"** significantly outweigh other classes, representing approximately **20.63%** and **19.56%** of the data, respectively.

# %% [markdown]
# #### Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from Augmentor) (11.1.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from Augmentor) (4.67.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from Augmentor) (1.26.4)
# Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset = str(data_dir_train) + '/'

import Augmentor

for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x78141423EAD0>: 100%|██████████| 500/500 [00:24<00:00, 20.79 Samples/s]
# Initialised with 380 image(s) found.
# Output directory set to /content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7813B8B67A50>: 100%|██████████| 500/500 [00:20<00:00, 24.94 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7813A62C33D0>: 100%|██████████| 500/500 [00:20<00:00, 24.78 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7813A62AB290>: 100%|██████████| 500/500 [01:40<00:00,  4.99 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7813A62D9E90>: 100%|██████████| 500/500 [01:24<00:00,  5.95 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7813A61C9390>: 100%|██████████| 500/500 [00:19<00:00, 25.95 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x781421510BD0>: 100%|██████████| 500/500 [00:41<00:00, 12.17 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7813A62224D0>: 100%|██████████| 500/500 [00:18<00:00, 27.57 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7813A62AF050>: 100%|██████████| 500/500 [00:17<00:00, 27.92 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
# Verifying the total count of images after the augmentation
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 9000

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
# extracting the augmented image paths in a list
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list_new[:5]
# Out:
# ['/content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028393.jpg_312807c7-05a5-4f09-9fa7-4db8dd3b005a.jpg',
#  '/content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030143.jpg_6c5ffc88-3c32-44ec-8289-f69e47f8943e.jpg',
#  '/content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030730.jpg_7110c1a9-3817-44db-bc23-4185d8d320d5.jpg',
#  '/content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026702.jpg_78eedc38-28fd-4348-aa2f-e8469a724ab3.jpg',
#  '/content/gdrive/My Drive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030826.jpg_4605d5b8-175e-4bd9-90fc-e33c93d5ffb4.jpg']

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new[:5]
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis']

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
import pandas as pd
df2 = pd.DataFrame(list(dataframe_dict_new.items()), columns=['Image Path', 'Label'])
new_df = pd.concat([lesions_df, df2], ignore_index=True)

# Check the shape
new_df.shape
# Out:
# (11243, 2)

# %%
# View the augmented image paths and labels in a new df
new_df.head()
# Out:
#                                           Image Path              Label
# 0  /content/gdrive/My Drive/Skin cancer ISIC The ...  actinic keratosis
# 1  /content/gdrive/My Drive/Skin cancer ISIC The ...  actinic keratosis
# 2  /content/gdrive/My Drive/Skin cancer ISIC The ...  actinic keratosis
# 3  /content/gdrive/My Drive/Skin cancer ISIC The ...  actinic keratosis
# 4  /content/gdrive/My Drive/Skin cancer ISIC The ...  actinic keratosis

# %%
# Inspecting the classes after adding 500 samples per label
new_df['Label'].value_counts()
# Out:
# Label
# pigmented benign keratosis    1462
# melanoma                      1438
# basal cell carcinoma          1380
# nevus                         1357
# squamous cell carcinoma       1181
# vascular lesion               1139
# actinic keratosis             1114
# dermatofibroma                1095
# seborrheic keratosis          1077
# Name: count, dtype: int64

# %%
# Inspecting the classes (% age wise) after adding 500 samples per label
round(new_df['Label'].value_counts(normalize=True)*100, 2)
# Out:
# Label
# pigmented benign keratosis    13.00
# melanoma                      12.79
# basal cell carcinoma          12.27
# nevus                         12.07
# squamous cell carcinoma       10.50
# vascular lesion               10.13
# actinic keratosis              9.91
# dermatofibroma                 9.74
# seborrheic keratosis           9.58
# Name: proportion, dtype: float64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### Create a training dataset

# %%
# data_dir_train="path to directory with training data + data created using augmentor"

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 11243 files belonging to 9 classes.
# Using 8995 files for training.

# %% [markdown]
# #### Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 11243 files belonging to 9 classes.
# Using 2248 files for validation.

# %% [markdown]
# #### Create your model (make sure to include normalization)

# %%
## your code goes here

model = Sequential([
  augmentation_data,
  layers.Rescaling(1./255),
  layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation=tf.nn.relu),
  layers.Dense(target_labels)
])

# %% [markdown]
# #### Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### Train your model

# %%
# %%time
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 67s 219ms/step - accuracy: 0.2815 - loss: 3.4444 - val_accuracy: 0.1904 - val_loss: 9.6055
# Epoch 2/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 88s 245ms/step - accuracy: 0.3859 - loss: 1.5771 - val_accuracy: 0.3866 - val_loss: 1.6486
# Epoch 3/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 61s 218ms/step - accuracy: 0.4566 - loss: 1.4096 - val_accuracy: 0.3923 - val_loss: 1.6847
# Epoch 4/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 93s 257ms/step - accuracy: 0.5075 - loss: 1.2617 - val_accuracy: 0.4262 - val_loss: 1.6315
# Epoch 5/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 80s 251ms/step - accuracy: 0.5414 - loss: 1.2041 - val_accuracy: 0.4613 - val_loss: 1.5469
# Epoch 6/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 79s 241ms/step - accuracy: 0.5631 - loss: 1.1282 - val_accuracy: 0.3697 - val_loss: 1.8648
# Epoch 7/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 83s 246ms/step - accuracy: 0.5876 - loss: 1.0666 - val_accuracy: 0.4070 - val_loss: 1.6925
# Epoch 8/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 82s 247ms/step - accuracy: 0.5935 - loss: 1.0157 - val_accuracy: 0.5245 - val_loss: 1.3898
# Epoch 9/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 81s 244ms/step - accuracy: 0.6224 - loss: 0.9587 - val_accuracy: 0.6148 - val_loss: 1.0067
# Epoch 10/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 74s 216ms/step - accuracy: 0.6355 - loss: 0.9468 - val_accuracy: 0.3612 - val_loss: 1.8532
# Epoch 11/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 89s 242ms/step - accuracy: 0.6484 - loss: 0.9194 - val_accuracy: 0.5529 - val_loss: 1.2614
# Epoch 12/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 83s 247ms/step - accuracy: 0.6601 - loss: 0.8784 - val_accuracy: 0.6557 - val_loss: 0.8582
# Epoch 13/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 70s 247ms/step - accuracy: 0.6728 - loss: 0.8387 - val_accuracy: 0.3812 - val_loss: 2.4143
# Epoch 14/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 73s 214ms/step - accuracy: 0.6903 - loss: 0.7995 - val_accuracy: 0.6246 - val_loss: 1.0638
# Epoch 15/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 91s 246ms/step - accuracy: 0.6953 - loss: 0.7845 - val_accuracy: 0.6370 - val_loss: 0.9974
# Epoch 16/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 76s 226ms/step - accuracy: 0.7111 - loss: 0.7609 - val_accuracy: 0.5116 - val_loss: 1.6918
# Epoch 17/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 62s 221ms/step - accuracy: 0.7155 - loss: 0.7353 - val_accuracy: 0.3243 - val_loss: 4.7581
# Epoch 18/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 90s 248ms/step - accuracy: 0.7029 - loss: 0.7866 - val_accuracy: 0.6375 - val_loss: 0.9477
# Epoch 19/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 82s 250ms/step - accuracy: 0.7144 - loss: 0.7374 - val_accuracy: 0.6628 - val_loss: 0.8754
# Epoch 20/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 60s 213ms/step - accuracy: 0.7387 - loss: 0.6848 - val_accuracy: 0.5276 - val_loss: 1.6592
# CPU times: user 19min 9s, sys: 1min 16s, total: 20min 25s
# Wall time: 26min 27s

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ***Observations:***
#
# 1. Implementing batch normalization in the model yielded a slight uptick in both training and validation accuracy.
# 2. Formulating an alternative model without batch normalization aims to investigate prospective improvements in accuracy.

# %% [markdown]
# #### Creating another model (without batch normalization)

# %%
# create the model
model = Sequential([
  augmentation_data,
  layers.Rescaling(1./255),  # Changed from layers.experimental.preprocessing.Rescaling
  layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation=tf.nn.relu),
  layers.Dense(target_labels)
])

# %% [markdown]
# #### Compiling the model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# ModelCheckpoint callback is employed alongside the model.fit() training process to periodically save the model
# or its weights (in a checkpoint file)
checkpoint = ModelCheckpoint("model.keras", monitor="val_accuracy", save_best_only=True, mode="auto", verbose=1)

# Early stop the training when a monitored metric ceases to show improvement
earlystop = EarlyStopping(monitor="val_accuracy", patience=5, mode="auto", verbose=1)

# %% [markdown]
# #### Training the model

# %%
# %%time
# train the model
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[checkpoint, earlystop]
)
# Out:
# Epoch 1/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.2326 - loss: 2.0134
# Epoch 1: val_accuracy improved from -inf to 0.40747, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 61s 207ms/step - accuracy: 0.2332 - loss: 2.0117 - val_accuracy: 0.4075 - val_loss: 1.5742
# Epoch 2/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.4357 - loss: 1.4834
# Epoch 2: val_accuracy improved from 0.40747 to 0.51068, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 91s 240ms/step - accuracy: 0.4359 - loss: 1.4829 - val_accuracy: 0.5107 - val_loss: 1.3024
# Epoch 3/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.5012 - loss: 1.3108
# Epoch 3: val_accuracy improved from 0.51068 to 0.55738, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 85s 250ms/step - accuracy: 0.5012 - loss: 1.3106 - val_accuracy: 0.5574 - val_loss: 1.1558
# Epoch 4/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.5402 - loss: 1.2196
# Epoch 4: val_accuracy improved from 0.55738 to 0.58007, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 80s 245ms/step - accuracy: 0.5402 - loss: 1.2195 - val_accuracy: 0.5801 - val_loss: 1.1083
# Epoch 5/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.5600 - loss: 1.1386
# Epoch 5: val_accuracy did not improve from 0.58007
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 81s 242ms/step - accuracy: 0.5601 - loss: 1.1384 - val_accuracy: 0.5658 - val_loss: 1.2322
# Epoch 6/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.5722 - loss: 1.1287
# Epoch 6: val_accuracy did not improve from 0.58007
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 71s 205ms/step - accuracy: 0.5724 - loss: 1.1283 - val_accuracy: 0.5472 - val_loss: 1.1619
# Epoch 7/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.6090 - loss: 1.0501
# Epoch 7: val_accuracy improved from 0.58007 to 0.65925, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 83s 210ms/step - accuracy: 0.6091 - loss: 1.0498 - val_accuracy: 0.6593 - val_loss: 0.9034
# Epoch 8/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.6432 - loss: 0.9374
# Epoch 8: val_accuracy improved from 0.65925 to 0.67660, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 69s 243ms/step - accuracy: 0.6432 - loss: 0.9373 - val_accuracy: 0.6766 - val_loss: 0.8623
# Epoch 9/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6615 - loss: 0.8858
# Epoch 9: val_accuracy did not improve from 0.67660
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 71s 203ms/step - accuracy: 0.6616 - loss: 0.8856 - val_accuracy: 0.6254 - val_loss: 1.0151
# Epoch 10/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6057 - loss: 1.0755
# Epoch 10: val_accuracy improved from 0.67660 to 0.67927, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 92s 237ms/step - accuracy: 0.6062 - loss: 1.0744 - val_accuracy: 0.6793 - val_loss: 0.8740
# Epoch 11/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7018 - loss: 0.8112
# Epoch 11: val_accuracy improved from 0.67927 to 0.71619, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 83s 242ms/step - accuracy: 0.7018 - loss: 0.8110 - val_accuracy: 0.7162 - val_loss: 0.7472
# Epoch 12/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7099 - loss: 0.7779
# Epoch 12: val_accuracy improved from 0.71619 to 0.73977, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 73s 210ms/step - accuracy: 0.7100 - loss: 0.7777 - val_accuracy: 0.7398 - val_loss: 0.7015
# Epoch 13/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.7350 - loss: 0.6996
# Epoch 13: val_accuracy did not improve from 0.73977
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 70s 246ms/step - accuracy: 0.7351 - loss: 0.6995 - val_accuracy: 0.6548 - val_loss: 0.9874
# Epoch 14/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7286 - loss: 0.7273
# Epoch 14: val_accuracy did not improve from 0.73977
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 70s 205ms/step - accuracy: 0.7287 - loss: 0.7268 - val_accuracy: 0.7211 - val_loss: 0.7385
# Epoch 15/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7464 - loss: 0.6609
# Epoch 15: val_accuracy improved from 0.73977 to 0.78158, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 93s 242ms/step - accuracy: 0.7465 - loss: 0.6607 - val_accuracy: 0.7816 - val_loss: 0.6038
# Epoch 16/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7663 - loss: 0.6266
# Epoch 16: val_accuracy did not improve from 0.78158
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 80s 237ms/step - accuracy: 0.7663 - loss: 0.6265 - val_accuracy: 0.7500 - val_loss: 0.6850
# Epoch 17/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7795 - loss: 0.5973
# Epoch 17: val_accuracy did not improve from 0.78158
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 84s 243ms/step - accuracy: 0.7795 - loss: 0.5972 - val_accuracy: 0.7789 - val_loss: 0.6394
# Epoch 18/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.7808 - loss: 0.6077
# Epoch 18: val_accuracy did not improve from 0.78158
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 81s 242ms/step - accuracy: 0.7809 - loss: 0.6075 - val_accuracy: 0.7722 - val_loss: 0.6143
# Epoch 19/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8039 - loss: 0.5144
# Epoch 19: val_accuracy improved from 0.78158 to 0.79804, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 72s 206ms/step - accuracy: 0.8039 - loss: 0.5145 - val_accuracy: 0.7980 - val_loss: 0.5451
# Epoch 20/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8012 - loss: 0.5449
# Epoch 20: val_accuracy did not improve from 0.79804
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 91s 239ms/step - accuracy: 0.8013 - loss: 0.5448 - val_accuracy: 0.7460 - val_loss: 0.7209
# Epoch 21/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7827 - loss: 0.5668
# Epoch 21: val_accuracy improved from 0.79804 to 0.80383, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 83s 242ms/step - accuracy: 0.7828 - loss: 0.5664 - val_accuracy: 0.8038 - val_loss: 0.5524
# Epoch 22/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8222 - loss: 0.4822
# Epoch 22: val_accuracy improved from 0.80383 to 0.81450, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 82s 241ms/step - accuracy: 0.8221 - loss: 0.4824 - val_accuracy: 0.8145 - val_loss: 0.5204
# Epoch 23/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8167 - loss: 0.4894
# Epoch 23: val_accuracy improved from 0.81450 to 0.83407, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 82s 242ms/step - accuracy: 0.8168 - loss: 0.4892 - val_accuracy: 0.8341 - val_loss: 0.4538
# Epoch 24/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8240 - loss: 0.4652
# Epoch 24: val_accuracy improved from 0.83407 to 0.84075, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 58s 205ms/step - accuracy: 0.8240 - loss: 0.4651 - val_accuracy: 0.8407 - val_loss: 0.4639
# Epoch 25/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8266 - loss: 0.4600
# Epoch 25: val_accuracy did not improve from 0.84075
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 92s 243ms/step - accuracy: 0.8265 - loss: 0.4600 - val_accuracy: 0.8221 - val_loss: 0.4855
# Epoch 26/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8283 - loss: 0.4452
# Epoch 26: val_accuracy improved from 0.84075 to 0.84297, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 72s 208ms/step - accuracy: 0.8284 - loss: 0.4451 - val_accuracy: 0.8430 - val_loss: 0.4484
# Epoch 27/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8267 - loss: 0.4561
# Epoch 27: val_accuracy improved from 0.84297 to 0.85632, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 88s 229ms/step - accuracy: 0.8268 - loss: 0.4561 - val_accuracy: 0.8563 - val_loss: 0.4336
# Epoch 28/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8374 - loss: 0.4342
# Epoch 28: val_accuracy did not improve from 0.85632
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 64s 225ms/step - accuracy: 0.8374 - loss: 0.4342 - val_accuracy: 0.8314 - val_loss: 0.4806
# Epoch 29/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8445 - loss: 0.4212
# Epoch 29: val_accuracy did not improve from 0.85632
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 88s 247ms/step - accuracy: 0.8445 - loss: 0.4211 - val_accuracy: 0.8332 - val_loss: 0.4741
# Epoch 30/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8196 - loss: 0.5101
# Epoch 30: val_accuracy did not improve from 0.85632
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 81s 244ms/step - accuracy: 0.8198 - loss: 0.5095 - val_accuracy: 0.8310 - val_loss: 0.4732
# Epoch 31/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8553 - loss: 0.3870
# Epoch 31: val_accuracy did not improve from 0.85632
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 82s 244ms/step - accuracy: 0.8554 - loss: 0.3868 - val_accuracy: 0.7829 - val_loss: 0.5850
# Epoch 32/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8497 - loss: 0.4027
# Epoch 32: val_accuracy improved from 0.85632 to 0.85899, saving model to model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 68s 243ms/step - accuracy: 0.8498 - loss: 0.4024 - val_accuracy: 0.8590 - val_loss: 0.4123
# Epoch 33/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8587 - loss: 0.3501
# Epoch 33: val_accuracy did not improve from 0.85899
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 67s 238ms/step - accuracy: 0.8588 - loss: 0.3501 - val_accuracy: 0.7727 - val_loss: 0.6534
# Epoch 34/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8042 - loss: 0.5678
# Epoch 34: val_accuracy did not improve from 0.85899
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 81s 235ms/step - accuracy: 0.8046 - loss: 0.5667 - val_accuracy: 0.8545 - val_loss: 0.4045
# Epoch 35/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8647 - loss: 0.3530
# Epoch 35: val_accuracy did not improve from 0.85899
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 84s 242ms/step - accuracy: 0.8648 - loss: 0.3530 - val_accuracy: 0.8314 - val_loss: 0.4644
# Epoch 36/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8613 - loss: 0.3631
# Epoch 36: val_accuracy did not improve from 0.85899
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 73s 208ms/step - accuracy: 0.8613 - loss: 0.3631 - val_accuracy: 0.8541 - val_loss: 0.4503
# Epoch 37/50
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8730 - loss: 0.3354
# Epoch 37: val_accuracy did not improve from 0.85899
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 90s 239ms/step - accuracy: 0.8731 - loss: 0.3354 - val_accuracy: 0.8577 - val_loss: 0.4313
# Epoch 37: early stopping
# CPU times: user 34min 27s, sys: 2min 16s, total: 36min 43s
# Wall time: 48min 50s

# %% [markdown]
# #### Visualize the model results

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)            │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_3 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 9)                   │           1,161 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,969,405 (45.66 MB)
#  Trainable params: 3,989,801 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 7,979,604 (30.44 MB)

# %%
# Plot the training curves

epochs_range = range(earlystop.stopped_epoch+1)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)

#Plot Model Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')

#Plot Model Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# #### Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# ***Observations:***
#
# 1. The ultimate model showcases well-balanced performance, displaying no signs of underfitting or overfitting.
#
# 2. The implementation of class rebalancing has notably enhanced the model's performance across both training and validation datasets.
#
# 3. Following 37 epochs, the final model attains an accuracy of 84% on the training set and approximately 79% on the validation set.
#
# 4. The narrow divergence between training and validation accuracies underscores the robust generalization capability of the final CNN model.
#
# 5. The addition of batch normalization failed to enhance both training and validation accuracy.

# %% [markdown]
# ### Model Evaluation

# %%
# Evaluating our model on one of the instances in the test set

from tensorflow.keras.preprocessing.image import load_img

image_path_test = os.path.join(data_dir_test, class_names[1], '*')
test_image = glob(image_path_test)
test_image = load_img(test_image[-1], target_size=(180, 180, 3))
plt.imshow(test_image)
plt.grid(False)

img = np.expand_dims(test_image, axis=0)
predicted = model.predict(img)
predicted = np.argmax(predicted)
predicted_class = class_names[predicted]
print("Actual Class: " + class_names[1] +'\n'+ "Predicted Class: " + predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# Actual Class: basal cell carcinoma
# Predicted Class: basal cell carcinoma
